# %%
import pandas as pd

# %%
data = pd.read_json("..\dataset\politifact_factcheck_data.json", lines = True)

# %%
data
# Out:
#             verdict statement_originator  \
# 0              true         Barack Obama
# 1             false           Matt Gaetz
# 2       mostly-true         Kelly Ayotte
# 3             false             Bloggers
# 4         half-true         Bobby Jindal
# ...             ...                  ...
# 21146  mostly-false         Donald Trump
# 21147         false     Donald Trump Jr.
# 21148  mostly-false          Chris Abele
# 21149         false             Bloggers
# 21150  mostly-false       Facebook posts
#
#                                                statement statement_date  \
# 0      John McCain opposed bankruptcy protections for...      6/11/2008
# 1      "Bennie Thompson actively cheer-led riots in t...       6/7/2022
# 2      Says Maggie Hassan was "out of state on 30 day...      5/18/2016
# 3      "BUSTED: CDC Inflated COVID Numbers, Accused o...       2/1/2021
# 4      "I'm the only (Republican) candidate that has ...      8/30/2015
# ...

# %%
data['factchecker'].value_counts()
# Out:
# factchecker
# Louis Jacobson      1834
# Ciara O'Rourke      1298
# Tom Kertscher       1199
# Jon Greenberg        972
# Amy Sherman          944
#                     ...
# Samantha Patrick       1
# Aidan Quigley          1
# Jeffrey Good           1
# Therese Bottomly       1
# Kathryn Hardison       1
# Name: count, Length: 563, dtype: int64

# %%
data['statement_source'].value_counts()
# Out:
# statement_source
# news             5762
# social_media     4985
# speech           3310
# campaign         1230
# advertisement    1143
# other            1063
# blog             1048
# television        603
# radio             546
# statement         515
# email             410
# meeting           293
# testimony         243
# Name: count, dtype: int64

# %%
data['statement_originator'].value_counts()
# Out:
# statement_originator
# Facebook posts                   1914
# Donald Trump                      950
# Viral image                       916
# Bloggers                          717
# Barack Obama                      563
#                                  ...
# Victoria Seaman                     1
# Mothers Against Drunk Driving       1
# Eric Gray                           1
# Kevin Levitas                       1
# Project Veritas                     1
# Name: count, Length: 4564, dtype: int64
